# %% [markdown]
# # Data Preprocessing

# %%
# import packages
import numpy as np
import pandas as pd
import re

# %% [markdown]
# As a review from the last notebook, we scraped speech transcripts from James Clear's website on his ["Great Speeches" page](https://jamesclear.com/great-speeches) (where we took the top 10 which are sorted alphabetically by the orator's last name) and the lyrics from all songs in bestselling albums of all time (according to this [Business Insider article](https://www.businessinsider.com/50-best-selling-albums-all-time-2016-9)) from [AZLyrics](https://www.azlyrics.com/).
#
# Below are what our raw dataframes look like. Not bad if I do say so myself. Of course, there's a lot of preprocessing that has to be done, but it looks like we properly collected the data.
#
# Edit: Temporarily, I will be using `speeches_raw.xlsx` and  `songs_raw.xlsx` dataset which are datasets generated taking the top 24 speeches and songs successfully scraped from the websites. I'm doing this so that I have a larger dataset to work with for the analysis notebook, which will make it more helpful when visualized and easier to describe what the data in general looks like. I later plan to debug scraping errors that started to appear when generating over 10 rows due to differences in URLs and page structure.
#
# My data where I only scraped the first 10 links for songs and speeches is in the `data_n=10` folder. This is mostly just to save the data somewhere where it won't be overwritten as I work with my longer dataframes.

# %%
speech_df = pd.read_excel('speeches_raw.xlsx', dtype=str)
speech_df
# speech_df.iat[2,2]
# Out:
#                         Orator  \
# 0     Chimamanda Ngozi Adichie
# 1                   Jeff Bezos
# 2                John C. Bogle
# 3                  Brené Brown
# 4                  John Cleese
# 5          William Deresiewicz
# 6              Richard Feynman
# 7                  Neil Gaiman
# 8              John W. Gardner
# 9            Elizabeth Gilbert
# 10           Albert E. N. Gray
# 11                 Bill Gurley
# 12             Richard Hamming
# 13             Richard Hamming
# 14                  Steve Jobs
# 15               Peter Kaufman
# 16  Admiral William H. McRaven
# 17       Arno Rafael Minkkinen
# 18              Charlie Munger
# 19              Charlie Munger
# 20              Charlie Munger
# 21             Nathan Myhrvold
# 22                Randy Pausch
# 23               Anna Quindlen
# 24                John Roberts
# 25                Ken Robinson
# 26                J.K. Rowling
# 27             George Saunders
# 28              Claude Shannon
# 29                 Jim Valvano
# 30                 Bret Victor
# 31        David Foster Wallace
#
#                                                 Title  \
# 0                        The Danger of a Single Story
# 1                 What Matters More Than Your Talents
# 2                                              Enough
# 3                                The Anatomy of Trust
# 4                            Creativity in Management
# 5                             Solitude and Leadership
# 6                                    Seeking New Laws
# 7                                       Make Good Art
# 8                                    Personal Renewal
# 9                        Your Elusive Creative Genius
# 10                  The Common Denominator of Success
# 11  Runnin’ Down a Dream: How to Succeed and Thriv...
# 12                                  Learning to Learn
# 13                              You and Your Research
# 14                 2005 Stanford Commencement Address
# 15         The Multidisciplinary Approach to Thinking
# 16                                      Make Your Bed
# 17                            Finding Your Own Vision
# 18           2007 USC Law School Commencement Address
# 19             A Lesson on Elementary, Worldly Wisdom
# 20                The Psychology of Human Misjudgment
# 21                Roadkill on the Information Highway
# 22                    Achieving Your Childhood Dreams
# 23             1999 Mount Holyoke Commencement Speech
# 24                                I Wish You Bad Luck
# 25                        Do Schools Kill Creativity?
# 26                     The Fringe Benefits of Failure
# 27                               Failures of Kindness
# 28                                  Creative Thinking
# 29                                      Don’t Give Up
# 31  https://jamesclear.com/great-speeches/this-is-...

# %%
song_df =  pd.read_excel('songs_raw.xlsx', dtype=str)
song_df
# Out:
#                      Artist                            Album  \
# 0           Michael Jackson                       "Thriller"
# 1                    Eagles               "Hotel California"
# 2              Led Zeppelin                "Led Zeppelin IV"
# 3                Pink Floyd                       "The Wall"
# 4                     AC/DC                  "Back In Black"
# 5              Garth Brooks                    "Double Live"
# 6     Hootie & The Blowfish              "Cracked Rear View"
# 7             Fleetwood Mac                        "Rumours"
# 8              Shania Twain                   "Come On Over"
# 9               The Beatles  "The Beatles (The White Album)"
# 10          Whitney Houston                  "The Bodyguard"
# 11                   Boston                         "Boston"
# 12             Garth Brooks                      "No Fences"
# 13                 Bee Gees           "Saturday Night Fever"
# 14             Led Zeppelin              "Physical Graffiti"
# 15        Bruce Springsteen             "Born In The U.S.A."
# 16                  Santana                   "Supernatural"
# 17                    Adele                             "21"
# 18           Britney Spears          "...Baby One More Time"
# 19             Garth Brooks                "Ropin' The Wind"
# 20  Prince & The Revolution                    "Purple Rain"
# 21          Whitney Houston                "Whitney Houston"
# 22                 Bon Jovi              "Slippery When Wet"
#
#                                                 Lyric  \
# 0   \n\r\nI said you wanna be startin' somethin'\n...
# 1   \n\r\nOn a dark desert highway, cool wind in m...
# 2   \n\r\nHey, hey mama, said the way you move\nGo...
# 3   \n\r\n(We came in)\n\nSo ya thought ya might l...
# 4   \n\r\nI'm rolling thunder pouring rain\nI'm co...
# 5   \n\r\nWe all came here for a party tonight\nAn...
# 6   \n\r\nYou got your big girl \nNow you've got y...
# 7   \n\r\nI know there's nothing to say\nSomeone h...
# 8   \n\r\nLet's go girls! Come on.\n\nI'm going ou...
# 9   \n\r\nOh, flew in by Miami Beach B.O.A.C.\nDid...
# 10  \n\r\nIf I should stay\nI would only be in you...
# 11  \n\r\nI looked out this morning and the sun wa...
# 12  \n\r\nThree thirty in the morning\nNot a soul ...
# 13  \n\r\nWell, you can tell by the way I use my w...
# 14  \n\r\nDrop down, baby, let your daddy see.\nDr...
# 15  \n\r\nBorn down in a dead man's town\nThe firs...
# 16  \n\r\nDeja ya 'migo sin ella no somos na' [4x]...
# 17  \n\r\nThere's a fire starting in my heart\nRea...
# 18  \n\r\nOh, baby, baby\nOh, baby, baby\n\nOh, ba...
# 19  \n\r\nFolks call me a maverick \r\nGuess I ain...
# 20  \n\r\nDearly beloved\nWe are gathered here tod...
# 21  \n\r\nI found out what I've been missing \nAlw...
# 22  \n\r\nThe weekend comes to this town \r\nSeven...
#
#                                     Artist_Link
# 0       https://www.azlyrics.com/j/jackson.html
# 1        https://www.azlyrics.com/e/eagles.html
# 2   https://www.azlyrics.com/l/ledzeppelin.html
# 3     https://www.azlyrics.com/p/pinkfloyd.html
# 4          https://www.azlyrics.com/a/acdc.html
# 5        https://www.azlyrics.com/b/brooks.html
# 6        https://www.azlyrics.com/h/hootie.html
# 7     https://www.azlyrics.com/f/fleetwood.html
# 8         https://www.azlyrics.com/t/twain.html
# 9       https://www.azlyrics.com/b/beatles.html
# 10      https://www.azlyrics.com/h/houston.html
# 11       https://www.azlyrics.com/b/boston.html
# 12       https://www.azlyrics.com/b/brooks.html
# 13      https://www.azlyrics.com/b/beegees.html
# 14  https://www.azlyrics.com/l/ledzeppelin.html
# 15  https://www.azlyrics.com/s/springsteen.html
# 16      https://www.azlyrics.com/s/santana.html
# 17        https://www.azlyrics.com/a/adele.html
# 18       https://www.azlyrics.com/s/spears.html
# 19       https://www.azlyrics.com/b/brooks.html
# 20       https://www.azlyrics.com/p/prince.html
# 21      https://www.azlyrics.com/h/houston.html
# 22      https://www.azlyrics.com/b/bonjovi.html

# %% [markdown]
# Below, I've combined our two raw data frames in the hopes that they can be preprocessed at the same time. Twenty rows may be a bit much for some people, but it's simple to take out rows so I felt it was best to have more rather than less. As an aside it also made webscraping a more interesting exercise since I needed to deal with different page and url formats.

# %%
comm_df =  pd.read_excel('communication_data.xlsx', dtype=str)
# let's remove those newlines at the start of our songs
comm_df['Corpus'] = comm_df['Corpus'].str.strip()
comm_df
# Out:
#                     Originator  \
# 0     Chimamanda Ngozi Adichie
# 1                   Jeff Bezos
# 2                John C. Bogle
# 3                  Brené Brown
# 4                  John Cleese
# 5          William Deresiewicz
# 6              Richard Feynman
# 7                  Neil Gaiman
# 8              John W. Gardner
# 9            Elizabeth Gilbert
# 10           Albert E. N. Gray
# 11                 Bill Gurley
# 12             Richard Hamming
# 13                  Steve Jobs
# 14               Peter Kaufman
# 15  Admiral William H. McRaven
# 16       Arno Rafael Minkkinen
# 17              Charlie Munger
# 18             Nathan Myhrvold
# 19                Randy Pausch
# 20               Anna Quindlen
# 21                John Roberts
# 22                Ken Robinson
# 23                J.K. Rowling
# 24             Michael Jackson
# 25                      Eagles
# 26                Led Zeppelin
# 27                  Pink Floyd
# 28                       AC/DC
# 29                Garth Brooks
# 30       Hootie & The Blowfish
# 31               Fleetwood Mac
# 32                Shania Twain
# 33                 The Beatles
# 34             Whitney Houston
# 35                      Boston
# 36                Garth Brooks
# 37                    Bee Gees
# 38                Led Zeppelin
# 39           Bruce Springsteen
# 40                     Santana
# 41                       Adele
# 42              Britney Spears
# 43                Garth Brooks
# 44     Prince & The Revolution
# 45             Whitney Houston
# 46                    Bon Jovi
#
#                                                 Title  \
# 0                        The Danger of a Single Story
# 1                 What Matters More Than Your Talents
# 2                                              Enough
# 3                                The Anatomy of Trust
# 4                            Creativity in Management
# 5                             Solitude and Leadership
# 6                                    Seeking New Laws
# 7                                       Make Good Art
# 8                                    Personal Renewal
# 9                        Your Elusive Creative Genius
# 10                  The Common Denominator of Success
# 11  Runnin’ Down a Dream: How to Succeed and Thriv...
# 12                                  Learning to Learn
# 13                 2005 Stanford Commencement Address
# 14         The Multidisciplinary Approach to Thinking
# 15                                      Make Your Bed
# 16                            Finding Your Own Vision
# 17           2007 USC Law School Commencement Address
# 18                Roadkill on the Information Highway
# 19                    Achieving Your Childhood Dreams
# 20             1999 Mount Holyoke Commencement Speech
# 21                                I Wish You Bad Luck
# 22                        Do Schools Kill Creativity?
# 23                     The Fringe Benefits of Failure
# 24                                         "Thriller"
# 25                                 "Hotel California"
# 26                                  "Led Zeppelin IV"
# 27                                         "The Wall"
# 28                                    "Back In Black"
# 29                                      "Double Live"
# 30                                "Cracked Rear View"
# 31                                          "Rumours"
# 32                                     "Come On Over"
# 33                    "The Beatles (The White Album)"
# 34                                    "The Bodyguard"
# 35                                           "Boston"
# 36                                        "No Fences"
# 37                             "Saturday Night Fever"
# 38                                "Physical Graffiti"
# 39                               "Born In The U.S.A."
# 40                                     "Supernatural"
# 41                                               "21"
# 42                            "...Baby One More Time"
# 43                                  "Ropin' The Wind"
# 44                                      "Purple Rain"
# 45                                  "Whitney Houston"
# 46                                "Slippery When Wet"
#
#                                                Corpus  \
# 0   I'm a storyteller. And I would like to tell yo...
# 1   As a kid, I spent my summers with my grandpare...
# 2   Here’s how I recall the wonderful story that s...
# 3   Oh, it just feels like an incredible understat...
# 4   You know, when Video Arts asked me if I'd like...
# 5   My title must seem like a contradiction. What ...
# 6   What I want to talk to you about tonight is st...
# 7   I never really expected to find myself giving ...
# 8   I'm going to talk about “Self-Renewal.” One of...
# 9   I am a writer. Writing books is my profession ...
# 10  Several years ago I was brought face to face w...
# 11  Thanks for having me. Believe it or not, I've ...
# 12  The first lecture is on orientation. What am I...
# 13  I am honored to be with you today at your comm...
# 14  I was asked to talk about the multidisciplinar...
# 15  President Powers, Provost Fenves, Deans, membe...
# 16  We are in the midst of sea change – a tidal wa...
# 17  Well, no doubt many of you are wondering why t...
# 18  Hi. I'm Nathan Myhrvold, and I'm gonna talk to...
# 19  It's wonderful to be here. What [they] didn't ...
# 20  I look at all of you today and I cannot help b...
# 21  Rain, somebody said, is like confetti from hea...
# 22  Good morning. How are you? \nIt's been great, ...
# 23  President Faust, members of the Harvard Corpor...
# 24  I said you wanna be startin' somethin'\nYou go...
# 25  On a dark desert highway, cool wind in my hair...
# 26  Hey, hey mama, said the way you move\nGonna ma...
# 27  (We came in)\n\nSo ya thought ya might like to...
# 28  I'm rolling thunder pouring rain\nI'm coming o...
# 29  We all came here for a party tonight\nAnd your...
# 30  You got your big girl \nNow you've got your yo...
# 31  I know there's nothing to say\nSomeone has tak...
# 32  Let's go girls! Come on.\n\nI'm going out toni...
# 33  Oh, flew in by Miami Beach B.O.A.C.\nDidn't ge...
# 34  If I should stay\nI would only be in your way\...
# 35  I looked out this morning and the sun was gone...
# 36  Three thirty in the morning\nNot a soul in sig...
# 37  Well, you can tell by the way I use my walk,\n...
# 38  Drop down, baby, let your daddy see.\nDrop dow...
# 39  Born down in a dead man's town\nThe first kick...
# 40  Deja ya 'migo sin ella no somos na' [4x]\n\n[4...
# 41  There's a fire starting in my heart\nReaching ...
# 42  Oh, baby, baby\nOh, baby, baby\n\nOh, baby, ba...
# 43  Folks call me a maverick \r\nGuess I ain't too...
# 44  Dearly beloved\nWe are gathered here today\nTo...
# 45  I found out what I've been missing \nAlways on...
# 46  The weekend comes to this town \r\nSeven days ...
#
#                                                  Link Text Type
# 0   https://jamesclear.com/great-speeches/the-dang...    speech
# num_digits = comm_df["Corpus"].map(lambda s: sum(c.isdigit() for c in s))
# print('Number of Numerical Chars per Row')
# print(num_digits)

# set cat to song or speech to see the total numerical chars for that category
# leave as empty string for whole df total
cat = ''
number_of_numerical_chars = sum(c.isdigit() for c in comm_df.loc[comm_df['Text Type'].str.contains(cat),'Corpus'].str.cat())
print('Total Number of Numerical Chars')
print(number_of_numerical_chars)
# Out:
# Total Number of Numerical Chars
# 1338

# %% [markdown]
# The next step is taking out newline characters and unspoken text from our speeches/lyrics. This includes text between square brackets (Used for what goes on in songs, like "[__ singer:]"), number characters and special characters (besides apostrophes). Notice that I start off replacing all of these with a space. This is to make sure words don't get joined if there's something like a newline of backslash between them. After all that, I replace contiguous/multiple spaces with a single space.
#
# Newlines are sort of a special case. As you'll see, when I get to sentiment analysis, the tools I plan to use (VADER and TextBlob) struggle with large corpora. As a result, we'll preserve newlines between verses (songs) and paragraphs (speeches).
#
# I won't be taking out numbers or certain special characters in this step. I originally planned to by adding the line
# `s = re.sub(r"[^a-z ']",' ',s)`, but later realized that punctuation helps nltk's lemmatizer figure out if a word if an adjective, noun or whatever. This is also a pretty simple step, so it might happen in the analysis notebooks. I will also not be taking out stop words and short words (len < 3) yet for the same reason.

# %%
# example strings
ex_str1 = '[Speaker clears throat]\nThis is an example of what a corpus might look like.'
ex_str2 = 'Using "\r\n" is the standard newline for Windows. \n is used for Linux and Macs. \r is seen for old Macs.'
ex_str3 = "@#$ Let $me a*dd80943 9te0xt with cha^rs we don't[ really don't](123#$%) want to keep."

def standardize_text(corpus):
    # remove text between square brakets (effects in lyric text)
    s = re.sub('\[.*?\]', ' ', corpus)
    # replace newlines characters with spaces
    s = re.sub('\r','',s)
    # set all letters to lower case
    s = s.lower()
    # replace weird apostrophe with standard one
    s = re.sub(r"’","'",s)
    # replace all but a few special characters
    s = re.sub(r"[^a-z\.,\?! \n']",' ',s)
    # remove extra spaces
    s = re.sub(' +', ' ',s)
    return s

print("Example 1:")
print(standardize_text(ex_str1))
print("Example 2:")
print(standardize_text(ex_str2))
# using the function I took out for lemmatization effectiveness
print("Example 3:")
print(standardize_text(ex_str3))
# Out:
# Example 1:
#
# this is an example of what a corpus might look like.
# Example 2:
# using
#  is the standard newline for windows.
#  is used for linux and macs. is seen for old macs.
# Example 3:
#  let me a dd te xt with cha rs we don't want to keep.

# %%
comm_df1 = comm_df.copy()
# comm_df = comm_df1

# %%
comm_df['Corpus'] = comm_df['Corpus'].apply(standardize_text)
song_mask = (comm_df['Text Type']=='song')
comm_df.loc[song_mask,'Corpus'] = comm_df.loc[song_mask,'Corpus'].apply(lambda s: re.sub('\n\n','\t',s))
comm_df.loc[song_mask,'Corpus'] = comm_df.loc[song_mask,'Corpus'].apply(lambda s: re.sub('\n',' ',s))
comm_df.loc[song_mask,'Corpus'] = comm_df.loc[song_mask,'Corpus'].apply(lambda s: re.sub('\t','\n',s))
# comm_df.iat[16,2]

# %% [markdown]
# #### Contractions

# %%
# get list of contractions
def get_contractions(df,txt_col):
    all_words = df[txt_col].str.cat(sep=' ')
    # could use regex, but more steps and this already runs fast
    unique_contractions = set([word for word in all_words.split() if "'" in word or "-" in word])
    return unique_contractions

# get contractions with their number of occurances
def get_contraction_count(df,txt_col):
    all_words = df[txt_col].str.cat(sep=' ')
    word_list = all_words.split()
    # could use regex, but more steps and this already runs fast
    contraction_dict = {word: 0 for word in word_list if "'" in word or "-" in word}
    for word in word_list:
        if "'" in word:
            contraction_dict[word] += 1
    # sort by count
    contraction_dict = {w: count for w, count in sorted(contraction_dict.items(), key=lambda item: item[1], reverse=True)}
    return contraction_dict

cont_set = get_contractions(comm_df,'Corpus')
get_contraction_count(comm_df,'Corpus')
# Out:
# {"i'm": 778,
#  "don't": 738,
#  "it's": 734,
#  "you're": 522,
#  "that's": 273,
#  "can't": 263,
#  "i've": 227,
#  "there's": 212,
#  "we're": 191,
#  "i'll": 185,
#  "didn't": 135,
#  "won't": 132,
#  "ain't": 121,
#  "'cause": 118,
#  "she's": 112,
#  "you'll": 106,
#  "they're": 100,
#  "i'd": 98,
#  "you've": 98,
#  "let's": 88,
#  "isn't": 72,
#  "doesn't": 69,
#  "he's": 68,
#  "what's": 58,
#  "we'll": 54,
#  "we've": 48,
#  "couldn't": 48,
#  "talkin'": 40,
#  "wasn't": 39,
#  "d'do": 39,
#  "goin'": 34,
#  "who's": 33,
#  "they'll": 32,
#  "'til": 31,
#  "here's": 30,
#  "you'd": 30,
#  "'bout": 28,
#  "stayin'": 28,
#  "hadn't": 27,
#  "wouldn't": 25,
#  "'em": 25,
#  "somethin'": 25,
#  "startin'": 24,
#  "livin'": 24,
#  "holdin'": 23,
#  "'n'": 22,
#  "we'd": 21,
#  "doin'": 21,
#  "aren't": 20,
#  "haven't": 19,
#  "lovin'": 18,
#  "thinkin'": 18,
#  "it'll": 16,
#  "they've": 15,
#  "people's": 15,
#  "'round": 15,
#  "everybody's": 15,
#  "nobody's": 14,
#  "she'll": 13,
#  "shouldn't": 13,
#  "d'da": 13,
#  "tryin'": 12,
#  "feelin'": 12,
#  "gettin'": 12,
#  "he'll": 11,
#  "he'd": 10,
#  "one's": 10,
#  "c'mon": 10,
#  "lookin'": 10,
#  "man's": 9,
#  "there'll": 9,
#  "cryin'": 9,
#  "nothin'": 9,
#  "mama's": 9,
#  "takin'": 9,
#  "weren't": 8,
#  "world's": 8,
#  "newton's": 8,
#  "love's": 8,
#  "yesterday's": 8,
#  "n'gai": 8,
#  "something's": 7,
#  "today's": 7,
#  "hasn't": 7,
#  "playin'": 7,
#  "daddy's": 7,
#  "workin'": 7,
#  "standin'": 7,
#  "gol'": 7,
#  "children's": 6,
#  "'": 6,
#  "life's": 6,
#  "god's": 6,
#  "they'd": 6,
#  "darlin'": 6,
#  "comin',": 6,
#  "prayin'": 6,
#  "tearin'": 6,
#  "'tween": 6,
#  "c'mon,": 6,
#  "movin'": 6,
#  "singin'": 6,
#  "don't.": 5,
#  "that'll": 5,
#  "nature's": 5,
#  "she'd": 5,
#  "someone's": 5,
#  "dyin'": 5,
#  "diggin'": 5,
#  "runnin'": 5,
#  "kickin'": 5,
#  "comin'": 5,
#  "rollin'": 5,
#  "darlin',": 5,
#  "katrina's": 5,
#  "fide's": 4,
#  "isn't.": 4,
#  "ship's": 4,
#  "else's": 4,
#  "tomorrow's": 4,
#  "everything's": 4,
#  "guy's": 4,
#  "head's": 4,
#  "sayin'": 4,
#  "mornin'": 4,
#  "showin'": 4,
#  "walkin'": 4,
#  "makin'": 4,
#  "fightin'": 4,
#  "'till": 4,
#  "waitin'": 4,
#  "dancin'": 4,
#  "smokin',": 4,
#  "smokin'": 4,
#  "draggin'": 4,
#  "marchin',": 4,
#  "girl's": 4,
#  "gun's": 4,
#  "stickin'": 4,
#  "don't,": 3,
#  "didn't.": 3,
#  "parents'": 3,
#  "about?'": 3,
#  ".'": 3,
#  "somebody's": 3,
#  "anyone's": 3,
#  "talkin',": 3,
#  "lyin'": 3,
#  "tellin'": 3,
#  "burnin'": 3,
#  "temperature's": 3,
#  "burin'": 3,
#  "men's": 3,
#  "must've": 3,
#  "jokin',": 3,
#  "tears'll": 3,
#  "need's": 3,
#  "chasin'": 3,
#  "lightnin'": 3,
#  "times'": 3,
#  "breakin'": 3,
#  "shakin',": 3,
#  "denyin'": 3,
#  "rockin'": 3,
#  "fillin'": 3,
#  "papa's": 3,
#  "huggin'": 3,
#  "forgettin'": 3,
#  "devil's": 3,
#  "america's": 2,
#  "husband's": 2,
#  "grandfather's": 2,
#  "nation's": 2,
#  "who've": 2,
#  "mom's": 2,
#  "sister's": 2,
#  "will's": 2,
#  "serious'": 2,
#  "marlow's": 2,
#  "artist's": 2,
#  "doesn't.": 2,
#  "didn't,": 2,
#  "how's": 2,
#  "o'clock": 2,
#  "gerde's": 2,
#  "danny's": 2,
#  "do.'": 2,
#  "layperson's": 2,
#  "you.'": 2,
#  "cat's": 2,
#  "time.'": 2,
#  "thing's": 2,
#  "person's": 2,
#  "a'": 2,
#  "foley's": 2,
#  "mother's": 2,
#  "squealin',": 2,
#  "baby's": 2,
#  "girls'": 2,
#  "city's": 2,
#  "master's": 2,
#  "turnin'": 2,
#  "blowin'": 2,
#  "rushin'": 2,
#  "sittin'": 2,
#  "rainin',": 2,
#  "levee's": 2,
#  "d'ya": 2,
#  "why'd": 2,
#  "satan's": 2,
#  "ridin'": 2,
#  "abusin'": 2,
#  "listenin'": 2,
#  "givin'": 2,
#  "askin'": 2,
#  "future's": 2,
#  "wastin'": 2,
#  "hopin'": 2,
#  "payin'": 2,
#  "blushin'": 2,
#  "headin'": 2,
#  "georgia's": 2,
#  "gideon's": 2,
#  "goin',": 2,
#  "cookin'": 2,
#  "tokin'": 2,
#  "jumpin',": 2,
#  "woman's": 2,
#  "leavin'": 2,
#  "dyin',": 2,
#  "knowin'": 2,
#  "i'm...": 2,
#  "'head": 2,
#  "good'n,": 2,
#  "changin'": 2,
#  "angel's": 2,
#  "everything'll": 2,
#  "sho'nuff": 2,
#  "feeling's": 2,
#  "body's": 2,
#  "boy's": 2,
#  "eden's": 2,
#  "roommate's": 1,
#  "winner's": 1,
#  "loser's": 1,
#  "poor's": 1,
#  "buffett's": 1,
#  "vonnegut's": 1,
#  "out.'": 1,
#  "person.'": 1,
#  "here.'": 1,
#  "who've,": 1,
#  "partner's": 1,
#  "would've": 1,
#  "y'all": 1,
#  "y'all.": 1,
#  "tonight's": 1,
#  "mozart's": 1,
#  "gogh's": 1,
#  "hussein's": 1,
#  "hitchcock's": 1,
#  "women's": 1,
#  "paul's": 1,
#  "joe's": 1,
#  "o'clock,": 1,
#  "couldn't.": 1,
#  "solemn'.": 1,
#  "employees'": 1,
#  "student's": 1,
#  "friend's": 1,
#  "can't.": 1,
#  "pandora's": 1,
#  "mendeleev's": 1,
#  "heisenberg's": 1,
#  "to's": 1,
#  "'s,": 1,
#  "fire.'": 1,
#  "mustn't": 1,
#  "reader's": 1,
#  "nothing's": 1,
#  "other's": 1,
#  "don't!": 1,
#  "day's": 1,
#  "tinker's": 1,
#  "smucker's.": 1,
#  "clair's": 1,
#  "coaches'": 1,
#  "freewheelin'": 1,
#  "point's": 1,
#  "elio's,": 1,
#  "sister's,": 1,
#  "knight's": 1,
#  "drew's": 1,
#  "culver's,": 1,
#  "taylor's": 1,
#  "peers'": 1,
#  "indiana's": 1,
#  "pete's": 1,
#  "bobby's": 1,
#  "people's,": 1,
#  "beethoven's": 1,
#  "senior's": 1,
#  "william's": 1,
#  "pilot's": 1,
#  "friends'": 1,
#  "apple's": 1,
#  "doctor's": 1,
#  "others'": 1,
#  "today.'": 1,
#  "else?'": 1,
#  "improvement.'": 1,
#  "ocean.'": 1,
#  "ideas'": 1,
#  "biology.'": 1,
#  "nature.'": 1,
#  "buckets'.": 1,
#  "statistician's": 1,
#  "x',": 1,
#  "x'.": 1,
#  "man!'": 1,
#  "simple.'": 1,
#  "spinoza's": 1,
#  "interest.'": 1,
#  "it.'": 1,
#  "and,'": 1,
#  "month.'": 1,
#  "puppy's": 1,
#  "reading.'": 1,
#  "nutcase.'": 1,
#  "spencer's": 1,
#  "guy?'": 1,
#  "for.'": 1,
#  "emily's": 1,
#  "before.'": 1,
#  "needs.'": 1,
#  "craig'": 1,
#  "you?'": 1,
#  "cake.'": 1,
#  "evening.'": 1,
#  "when's": 1,
#  "mine?'": 1,
#  "off'": 1,
#  "watsa's": 1,
#  "mistake.'": 1,
#  "bono's": 1,
#  "before?'": 1,
#  "peter.'": 1,
#  "money.'": 1,
#  "charlie.'": 1,
#  "albert'": 1,
#  "one'": 1,
#  "absolutely'": 1,
#  "long.'": 1,
#  "suppliers.'": 1,
#  "years.'": 1,
#  "being's": 1,
#  "university's": 1,
#  "o'clock.": 1,
#  "talbot's": 1,
#  "saarinen's": 1,
#  "leica's.": 1,
#  "d'art": 1,
#  "gibson's": 1,
#  "sotheby's": 1,
#  "harry's": 1,
#  "dean's": 1,
#  "cicero's.": 1,
#  "darwin's": 1,
#  "hathaway's": 1,
#  "chauffeur's": 1,
#  "uncle's": 1,
#  "lovers'": 1,
#  "pilgrim's": 1,
#  "users'": 1,
#  "principle's": 1,
#  "humans'": 1,
#  "minicomputers'": 1,
#  "industry's": 1,
#  "technology's": 1,
#  "distribution's": 1,
#  "'em.": 1,
#  "freedom's": 1,
#  "family's": 1,
#  "who'd": 1,
#  "lampoon's": 1,
#  "what've": 1,
#  "deal's": 1,
#  "block's": 1,
#  "all's": 1,
#  "guests'": 1,
#  "charlie's": 1,
#  "that'd": 1,
#  "imagineering's": 1,
#  "forward.'": 1,
#  "yourself'": 1,
#  "living.'": 1,
#  "it'": 1,
#  "me.'": 1,
#  "parent's": 1,
#  "years'": 1,
#  "shakespeare's": 1,
#  "daughter's": 1,
#  "phone's": 1,
#  "wizard'": 1,
#  "life',": 1,
#  "international's": 1,
#  "country's": 1,
#  "cunnin',": 1,
#  "declinin'": 1,
#  "rubbin'": 1,
#  "spyin'": 1,
#  "hustlin',": 1,
#  "stealin',": 1,
#  "heaven's": 1,
#  "evil's": 1,
#  "lurkin'": 1,
#  "creepin'": 1,
#  "y'all's": 1,
#  "corpse's": 1,
#  "fire's": 1,
#  "yearnin'": 1,
#  "could've,": 1,
#  "could've": 1,
#  "burnin',": 1,
#  "stranger's": 1,
#  "wonderin'": 1,
#  "'ya?": 1,
#  "smilin'": 1,
#  "flamin'": 1,
#  "'fore": 1,
#  "horses'": 1,
#  "tyrant's": 1,
#  "piper's": 1,
#  "rustin'": 1,
#  "river's": 1,
#  "rainbow's": 1,
#  "mamma's": 1,
#  "carolyne's": 1,
#  "should've": 1,
#  "m'lord": 1,
#  "bugger's": 1,
#  "lightning's": 1,
#  "good's": 1,
#  "puttin'": 1,
#  "pushin',": 1,
#  "shovin',": 1,
#  "squeezin'": 1,
#  "grabbin',": 1,
#  "stabbin'": 1,
#  "beatin'": 1,
#  "keepin'": 1,
#  "grinnin'": 1,
#  "spittin'": 1,
#  "bitin'": 1,
#  "tie's": 1,
#  "dar's": 1,
#  "stipe's": 1,
#  "where's": 1,
#  "momma's": 1,
#  "hearin'": 1,
#  "p.e.'s": 1,
#  "walkin',": 1,
#  "up's": 1,
#  "john's": 1,
#  "ya'": 1,
#  "pumpin'": 1,
#  "watchin'": 1,
#  "job's": 1,
#  "usin'": 1,
#  "air's": 1,
#  "t'aime": 1,
#  "drinkin'": 1,
#  "pluggin'": 1,
#  "crankin'": 1,
#  "jeweler's": 1,
#  "rocky's": 1,
#  "dylan's": 1,
#  "father's": 1,
#  "braggin'": 1,
#  "climbin'": 1,
#  "can'tcha": 1,
#  "lot's": 1,
#  "sleepin'": 1,
#  "everybody'd": 1,
#  "band's": 1,
#  "can'tch": 1,
#  "pacin'": 1,
#  "buildin'": 1,
#  "sky's": 1,
#  "siftin'": 1,
#  "starin'": 1,
#  "provin'": 1,
#  "hurtin'": 1,
#  "january's": 1,
#  "drivin'": 1,
#  "complainin'": 1,
#  "bein'": 1,
#  "mornin'.": 1,
#  "walkin'.": 1,
#  "glowin'": 1,
#  "warnin'.": 1,
#  "wind'll": 1,
#  "flyin'": 1,
#  "the'": 1,
#  "marchin'": 1,
#  "oil's": 1,
#  "groovin'": 1,
#  "koni's": 1,
#  "denyin',": 1,
#  "sinkin'": 1,
#  "sailin'": 1,
#  "racin',": 1,
#  "racin'": 1,
#  "twistin'": 1,
#  "laughin'": 1,
#  "end's": 1,
#  "n'": 1,
#  "knockin'": 1,
#  "shakin'": 1,
#  "y'": 1,
#  "leavin',": 1,
#  "outside's": 1,
#  "wayne's": 1,
#  "pa's": 1,
#  "trooper's": 1,
#  "night's": 1,
#  "winter's": 1,
#  "lover's": 1,
#  "boys'": 1,
#  "radio's": 1,
#  "laugh's": 1,
#  "street's": 1,
#  "'migo": 1,
#  "na'": 1,
#  "it'd": 1,
#  "battle's": 1,
#  "dignity's": 1,
#  "blindin'": 1,
#  "somethin'.": 1,
#  "tickin'": 1,
#  "flowin'": 1,
#  "what'cha": 1,
#  "avoidin'": 1,
#  "havin'": 1,
#  "bustin'": 1,
#  "back's": 1,
#  "emptyin'": 1,
#  "evenin'": 1,
#  "oilin'": 1,
#  "lesson's": 1,
#  "trucker's": 1,
#  "daddy'd": 1,
#  "ol'": 1,
#  "farmer's": 1,
#  "ranger's": 1,
#  "dreamer's": 1,
#  "how'd": 1,
#  "makin',": 1,
#  "computer's": 1,
#  "ket's": 1,
#  "beggin'": 1,
#  "mind's": 1,
#  "trippin'": 1,
#  "yearnin',": 1,
#  "i'm,": 1,
#  "growin'": 1,
#  "negro's": 1,
#  "can't,": 1,
#  "angie's": 1,
#  "moment's": 1,
#  "passion's": 1,
#  "union's": 1,
#  "tommy's": 1,
#  "senorita's": 1,
#  "d's": 1,
#  "bottle's": 1,
#  "kid's": 1}

# %% [markdown]
# Well, that's a lot of words with apostrophe. I'll do my best to batch process these but it won't be perfect. To get a better understanding of which words occur more, I created `get_contraction_count(df,txt_col)` since it's good if I don't accidentally miss common contractions that weren't considered in my batch fixes.
#
# One of the next steps will be removing two letter words (since they normally don't mean anything in isolation) so we'll be able to remove words that end with `'s`. Yes, it can also denote possession, but the noun is the part we want if that's the case. It also mean's `i'm` and `it's` (two of the top 3 contractions) will end up being completely removed.

# %%
contractions_or_slang = {
    "c'mon": "come on",
    "i'm": "i am",
    "'em": 'them',
    "'n'": 'and',
    "'fore": 'before',
    "'round": 'around',
    "y'all": "you all",
    "ain't": 'is not',
    "'bout": "about",
    "'cause": 'because',
    "'til": "until",
    "d'ya": "would you",
    "'tween": "between",
    "wanna": "want to",
    "won't": "will not",
    "ya": "you",
    "'ya": "you",
    "m'lord": "my lord",
    "t'aime": 'love you', 
    # yes, this was used somewhere
    "y'all's": "you all is",
    # assumed typo
    "'till": "until",
    # ignored - few occurances
    "d'do": '', 
    "d'da":''
}

def expand_contraction(s):
    s = s.group(0)
    global contractions_or_slang
    if s in contractions_or_slang:
        return contractions_or_slang[s]
    elif "'" not in s or len(s) < 3:
        return s
    # whether possesion or __ is, 's does not have significant meaning
    elif s[-2:] == "'s":
        return s[:-2]
    elif s[-3:] == "n't":
        return s[:-3] + ' not'
    elif s[-3:] == "'re":
        return s[:-3] + ' are'
    elif s[-2:] == "'d":
        return s[:-2] + ' would'
    elif s[-3:] == "'ve":
        return s[:-3] + ' have'
    elif s[-3:] == "'ll":
        return s[:-3] + ' will'
    elif s[-3:] == "in'":
        return s[:-1] + 'g'
    elif "'" == s[-1]:
        return s[:-1]
    return s

## After initial creation of the function
# [word for word in list(map(expand_contraction, cont_set)) if "'" in word]
# >>> ["'till", "o'clock", "t'aime", "d'do", "d'da", "'ya"]

# %% [markdown]
# So it seems like we've dealt with the majority of contractions without hitch. The few weird ones commented above will be accounted for with some assumptions. "'till" is probably a typo of "'til" (ie. "until"), "o'clock" is acceptable, t'aime is French for "love you" and everything afterword is a bit odd. They'll probably be removed in tf-idf (very low count from `get_contraction_count`), but I'll keep the words they probably represent. I'm removing "d'do" and "d'da" because they don't hold any meaning.

# %%
def resolve_contractions_in_corpus(corpus):
    r=re.sub("[\w']+",expand_contraction,corpus)
    return r
    
# try it out on MJ's "Thriller" text
resolve_contractions_in_corpus(comm_df.at[2,'Corpus'])[:500]
# Out:
# 'here how i recall the wonderful story that sets the theme for my remarks today at a party given by a billionaire on shelter island, the late kurt vonnegut informs his pal, the author joseph heller, that their host, a hedge fund manager, had made more money in a single day than heller had earned from his wildly popular novel catch over its whole history. heller responds, yes, but i have something he will never have . . . enough. \nenough. i was stunned by its simple eloquence, to say nothing of it'

# %% [markdown]
# This looks clean, so we'll apply this function to the 'Corpus' column of our DataFrame. It's very apparent that there's a lot of repetition in this first song which is something true for most music. We'll keep in stop words and words less than 3 characters for now, and save a copy of this dataset with clean text and punctuation. These will be removed below when we clean the data to get a dataset better for Bag of Words (unordered) techniques.

# %%
comm_df['Corpus'] = comm_df['Corpus'].apply(resolve_contractions_in_corpus)
comm_df.to_excel('communication_data_clean.xlsx',index=False)
comm_df
# Out:
#                     Originator  \
# 0     Chimamanda Ngozi Adichie
# 1                   Jeff Bezos
# 2                John C. Bogle
# 3                  Brené Brown
# 4                  John Cleese
# 5          William Deresiewicz
# 6              Richard Feynman
# 7                  Neil Gaiman
# 8              John W. Gardner
# 9            Elizabeth Gilbert
# 10           Albert E. N. Gray
# 11                 Bill Gurley
# 12             Richard Hamming
# 13                  Steve Jobs
# 14               Peter Kaufman
# 15  Admiral William H. McRaven
# 16       Arno Rafael Minkkinen
# 17              Charlie Munger
# 18             Nathan Myhrvold
# 19                Randy Pausch
# 20               Anna Quindlen
# 21                John Roberts
# 22                Ken Robinson
# 23                J.K. Rowling
# 24             Michael Jackson
# 25                      Eagles
# 26                Led Zeppelin
# 27                  Pink Floyd
# 28                       AC/DC
# 29                Garth Brooks
# 30       Hootie & The Blowfish
# 31               Fleetwood Mac
# 32                Shania Twain
# 33                 The Beatles
# 34             Whitney Houston
# 35                      Boston
# 36                Garth Brooks
# 37                    Bee Gees
# 38                Led Zeppelin
# 39           Bruce Springsteen
# 40                     Santana
# 41                       Adele
# 42              Britney Spears
# 43                Garth Brooks
# 44     Prince & The Revolution
# 45             Whitney Houston
# 46                    Bon Jovi
#
#                                                 Title  \
# 0                        The Danger of a Single Story
# 1                 What Matters More Than Your Talents
# 2                                              Enough
# 3                                The Anatomy of Trust
# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Stemming and lemmatization are important for NLP when looking at word count, topics and other applications that don't care about the right usage of verbs or complete words. This means these techniques should not be used if you are trying text synthesis, question answering or sentiment analysis.
#
# Stemmers use an algorithm to get the stem/root of given words. This way, if you have variations on a word like "walk" such as "walked" and "walking", they would all be stemmed to "walk" and we'd have an appropriate count of the use of the verb in our corpus. The SnowballStemmer is preferred for achieving the best practical results, but if you're curious about the different popular types and how they differ, it is explained in more detail below.
#
# Lemmatizers work to achieve the same goal as stemmers, except the approach is different. When talking about lemmas for NLP, we are talking about a word with a similar meaning to the word being lemmatized. Of course, this is to keep words consistent - a lemma doesn't always need to be different from the input word. For example, "create", "making" and "make" lemmatized could all be "make". Now this might not be true for the lemmatizer we'll use, but this gives you an idea on how it could get rid of noise from synonyms. We'll take a more detailed look at how lemmatizers work in practice below.
#
# Now that we also don't care about punctuation and newlines, let's quickly get rid of those.

# %%
def remove_special_chars(corpus):
    # replace remaining non-alpha chars with space
    s = re.sub('[^a-z ]', ' ', corpus)
    # remove extra spaces
    s = re.sub(' +', ' ',s)
    return s

comm_df['Corpus'] = comm_df['Corpus'].apply(remove_special_chars)

# %% [markdown]
# ### Stemming

# %% [markdown]
# The three stemmers we'll discuss in this notebook are Porter, Snowball and Lancaster. My information is from [here](https://stackoverflow.com/questions/10554052/what-are-the-major-differences-and-benefits-of-porter-and-lancaster-stemming-alg) but I'll summarize it below before testing them out on some words.
#
# **Popular Stemmers:**
# * **Porter:**
# * **Snowball (Porter2):**
# * **Lancaster:**

# %%
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer # aka Porter2
from nltk.stem import LancasterStemmer

ps = PorterStemmer()
ss = SnowballStemmer('english')
ls = LancasterStemmer()

# no difference in results
account_ls = ['account','accountant','accountable','accounting','accountability']
# note how Lancaster is more aggressive
organize_ls = ['organ','organize','organized','organization','organizer','organizable','organizational']
# first time we see a difference between Porter and Snowball
stud_ls = ['stud','student','studious','studiously','studiousness','study','studies','studentized','studied','studying']

# choose an above list or make your own
l = stud_ls
print('Porter Stemmer')
print(list(map(ps.stem,l)))
print('\nSnowball Stemmer')
print(list(map(ss.stem,l)))
print('\nLancaster Stemmer')
print(list(map(ls.stem,l)))
# Out:
# Porter Stemmer
# ['stud', 'student', 'studiou', 'studious', 'studious', 'studi', 'studi', 'student', 'studi', 'studi']
#
# Snowball Stemmer
# ['stud', 'student', 'studious', 'studious', 'studious', 'studi', 'studi', 'student', 'studi', 'studi']
#
# Lancaster Stemmer
# ['stud', 'stud', 'study', 'study', 'study', 'study', 'study', 'stud', 'study', 'study']

# %% [markdown]
# From what we've seen on the example lists I created, there isn't much difference between Porter and Snowball stemmer. Since I've seen Snowball used most commonly (and because the SO link says it's usually the best and faster than Porter), this is the one I'll be using for my stemmed version of the corpora. Lancaster seems a bit too indiscriminant. I'm not sure how much faster it is, but for a small dataset like mine it definitely is not worth the information I'd lose.
#
# I have read that lemmatization usually works better, but because it isn't guarenteed. It is at least important to be aware of stemming even if it doesn't always work the best. Since applying stemmers is easy, we won't create a separate version of the stemmed corpora, but we will compare how it differs from lemmatization in later notebooks.

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# Lemmatization is the process of replacing words similar in meaning with one select synonym. This is done so that all these different ways of saying the same thing appear under one word and be analysed together. For us, avoiding the manual process is great because it is quite time consuming and good knowledge of how words are used. Not to say you can't do it, but it's much better to use the premade language tools found in Python libraries.
#
# NLTK's WordNetLemmatizer is what we'll be using today. Know there are other lemmatizers from SpaCy, Textblob and probably other libraries, but we've already been using NLTK plus it is widely used so that's what I'll be sticking with today.

# %%
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
import re


def get_lemmas(corpus):
    word_tokens = word_tokenize(corpus)
    lemmatizer = WordNetLemmatizer()
    token_pos_tuple = pos_tag(word_tokens)
    pos_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "R": wordnet.ADV,
                "V": wordnet.VERB}
    token_wn_pos = list(map(lambda p: (p[0],pos_dict.get(p[1][0],wordnet.NOUN)),token_pos_tuple))
    s = ' '.join(list(map(lambda p: lemmatizer.lemmatize(p[0],p[1]),token_wn_pos)))
    return re.sub(r' ([\.\?!,])','\\1',s)

get_lemmas("geese are cute but vicious. wordnet makes my nlp analysis easier and better than it would otherwise be.")
# get_lemmas("geese")
# >>> "geese"
# get_lemmas(<geese in a sentence where it's clear it's a noun>)
# >>> <goose with rest of lemmatized sentence>
# Out:
# 'goose be cute but vicious. wordnet make my nlp analysis easy and good than it would otherwise be.'

# %%
lemma_df = comm_df.copy()
lemma_df['Corpus'] = lemma_df['Corpus'].apply(get_lemmas)
lemma_df
# Out:
#                     Originator  \
# 0     Chimamanda Ngozi Adichie
# 1                   Jeff Bezos
# 2                John C. Bogle
# 3                  Brené Brown
# 4                  John Cleese
# 5          William Deresiewicz
# 6              Richard Feynman
# 7                  Neil Gaiman
# 8              John W. Gardner
# 9            Elizabeth Gilbert
# 10           Albert E. N. Gray
# 11                 Bill Gurley
# 12             Richard Hamming
# 13                  Steve Jobs
# 14               Peter Kaufman
# 15  Admiral William H. McRaven
# 16       Arno Rafael Minkkinen
# 17              Charlie Munger
# 18             Nathan Myhrvold
# 19                Randy Pausch
# 20               Anna Quindlen
# 21                John Roberts
# 22                Ken Robinson
# 23                J.K. Rowling
# 24             Michael Jackson
# 25                      Eagles
# 26                Led Zeppelin
# 27                  Pink Floyd
# 28                       AC/DC
# 29                Garth Brooks
# 30       Hootie & The Blowfish
# 31               Fleetwood Mac
# 32                Shania Twain
# 33                 The Beatles
# 34             Whitney Houston
# 35                      Boston
# 36                Garth Brooks
# 37                    Bee Gees
# 38                Led Zeppelin
# 39           Bruce Springsteen
# 40                     Santana
# 41                       Adele
# 42              Britney Spears
# 43                Garth Brooks
# 44     Prince & The Revolution
# 45             Whitney Houston
# 46                    Bon Jovi
#
#                                                 Title  \
# 0                        The Danger of a Single Story
# 1                 What Matters More Than Your Talents
# 2                                              Enough
# 3                                The Anatomy of Trust
# 4                            Creativity in Management
# 5                             Solitude and Leadership
# 6                                    Seeking New Laws
# 7                                       Make Good Art
# 8                                    Personal Renewal
# 9                        Your Elusive Creative Genius
# 10                  The Common Denominator of Success
# 11  Runnin’ Down a Dream: How to Succeed and Thriv...
# 12                                  Learning to Learn
# 13                 2005 Stanford Commencement Address
# 14         The Multidisciplinary Approach to Thinking
# 15                                      Make Your Bed
# 16                            Finding Your Own Vision
# 17           2007 USC Law School Commencement Address
# 18                Roadkill on the Information Highway
# 3   https://jamesclear.com/great-speeches/the-anat...    speech
# 4   https://jamesclear.com/great-speeches/creativi...    speech
# 5   https://jamesclear.com/great-speeches/solitude...    speech
# 6   https://jamesclear.com/great-speeches/seeking-...    speech
# 7   https://jamesclear.com/great-speeches/make-goo...    speech
# 8   https://jamesclear.com/great-speeches/personal...    speech
# 9   https://jamesclear.com/great-speeches/your-elu...    speech
# 10  https://jamesclear.com/great-speeches/the-comm...    speech
# 11  https://jamesclear.com/great-speeches/runnin-d...    speech
# 12  https://jamesclear.com/great-speeches/learning...    speech
# 13  https://jamesclear.com/great-speeches/2005-sta...    speech
# 14  https://jamesclear.com/great-speeches/the-mult...    speech
# 15  https://jamesclear.com/great-speeches/make-you...    speech
# 16  https://jamesclear.com/great-speeches/finding-...    speech
# 17  https://jamesclear.com/great-speeches/2007-usc...    speech
# 18  https://jamesclear.com/great-speeches/roadkill...    speech
# 19  https://jamesclear.com/great-speeches/achievin...    speech
# 20  https://jamesclear.com/great-speeches/1999-mou...    speech
# 21  https://jamesclear.com/great-speeches/i-wish-y...    speech
# 22  https://jamesclear.com/great-speeches/do-schoo...    speech
# 23  https://jamesclear.com/great-speeches/the-frin...    speech
# 24            https://www.azlyrics.com/j/jackson.html      song
# 25             https://www.azlyrics.com/e/eagles.html      song
# 26        https://www.azlyrics.com/l/ledzeppelin.html      song
# 27          https://www.azlyrics.com/p/pinkfloyd.html      song
# 28               https://www.azlyrics.com/a/acdc.html      song
# 29             https://www.azlyrics.com/b/brooks.html      song
# 30             https://www.azlyrics.com/h/hootie.html      song
# 31          https://www.azlyrics.com/f/fleetwood.html      song
# 32              https://www.azlyrics.com/t/twain.html      song
# 33            https://www.azlyrics.com/b/beatles.html      song
# 34            https://www.azlyrics.com/h/houston.html      song
# 35             https://www.azlyrics.com/b/boston.html      song
# 36             https://www.azlyrics.com/b/brooks.html      song
# 37            https://www.azlyrics.com/b/beegees.html      song
# 38        https://www.azlyrics.com/l/ledzeppelin.html      song
# 39        https://www.azlyrics.com/s/springsteen.html      song
# 40            https://www.azlyrics.com/s/santana.html      song
# 41              https://www.azlyrics.com/a/adele.html      song
# 42             https://www.azlyrics.com/s/spears.html      song
# 43             https://www.azlyrics.com/b/brooks.html      song
# 44             https://www.azlyrics.com/p/prince.html      song
# 45            https://www.azlyrics.com/h/houston.html      song
# 46            https://www.azlyrics.com/b/bonjovi.html      song

# %%
from nltk.corpus import stopwords

def remove_stopwords(corpus):
    return ' '.join([word for word in corpus.split() if word not in stopwords.words('english') and len(word) > 2])

comm_df['Corpus'] = comm_df['Corpus'].apply(remove_stopwords)
comm_df['Corpus']
# Out:
# 0     storyteller would like tell personal stories l...
# 1     kid spent summers grandparents ranch texas hel...
# 2     recall wonderful story sets theme remarks toda...
# 3     feels like incredible understatement say grate...
# 4     know video arts asked would like talk creativi...
# 5     title must seem like contradiction solitude le...
# 6     want talk tonight strictly speaking character ...
# 7     never really expected find giving advice peopl...
# 8     going talk self renewal one fundamental tasks ...
# 9     writer writing books profession course also gr...
# 10    several years ago brought face face disturbing...
# 11    thanks believe thinking giving particular pres...
# 12    first lecture orientation trying purpose cours...
# 13    honored today commencement one finest universi...
# 14    asked talk multidisciplinary approach thinking...
# 15    president powers provost fenves deans members ...
# 16    midst sea change tidal wave might accurate med...
# 17    well doubt many wondering speaker old well ans...
# 18    nathan myhrvold gonna talk today roadkill info...
# 19    wonderful tell lecture series used called last...
# 20    look today cannot help see twenty five years a...
# 21    rain somebody said like confetti heaven even h...
# 22    good morning great blown away whole thing fact...
# 23    president faust members harvard corporation bo...
# 24    said want starting something got starting some...
# 25    dark desert highway cool wind hair warm smell ...
# 26    hey hey mama said way move gonna make sweat go...
# 27    came thought might like show feel warm thrill ...
# 28    rolling thunder pouring rain coming like hurri...
# 29    came party tonight gonna get left get right ch...
# 30    got big girl got young one wondering day could...
# 31    know nothing say someone taken place times bad...
# 32    let girls come going tonight feeling alright g...
# 33    flew miami beach get bed last night way paper ...
# 34    stay would way know think every step way alway...
# 35    looked morning sun gone turned music start day...
# 36    three thirty morning soul sight city looking l...
# 37    well tell way use walk woman man time talk mus...
# 38    drop baby let daddy see drop lady dream well m...
# 39    born dead man town first kick took hit ground ...
# 40    deja migo sin ella somos tika gai simba gai ya...
# 41    fire starting heart reaching fever pitch bring...
# 42    baby baby baby baby baby baby supposed know so...
# 43    folks call maverick guess diplomatic never kin...
# 44    dearly beloved gathered today get thing called...
# 45    found missing always run looking someone like ...
# 46    weekend comes town seven days soon ones make b...
# Name: Corpus, dtype: object

# %% [markdown]
# Saving for Bag of Words analysis (where order doesn't matter).

# %%
comm_df.to_excel('communication_data_BoW.xlsx',index=False)

# %% [markdown]
# ### TF-IDF

# %% [markdown]
# TF-IDF stands for Term Frequency-Inverse Document Frequency and is a way to numerically measure how important words are within the document. Term frequency is the number of times a word appears over the number of words in a document. IDF is the same for all documents because it is the log of number of documents over the number of documents containing that word.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

ti_vectorizer = TfidfVectorizer()
X = ti_vectorizer.fit_transform(lemma_df['Corpus'])

# %%
# index of the row to base tf off of
i=0

first_doc_df = pd.DataFrame(X[i].T.todense(), index=ti_vectorizer.get_feature_names(), columns=["TF-IDF"])
first_doc_df = first_doc_df.sort_values('TF-IDF', ascending=False)
first_doc_df.head(20)
# first_doc_df.tail(20)
# Out:
#             TF-IDF
# be        0.380809
# the       0.330233
# to        0.258831
# of        0.255856
# and       0.249906
# story     0.227415
# that      0.211230
# have      0.190404
# in        0.166604
# african   0.164908
# roommate  0.136730
# nigerian  0.136730
# my        0.136697
# single    0.116641
# not       0.101152
# nigeria   0.099440
# about     0.099254
# africa    0.097040
# read      0.092386
# what      0.078980

# %% [markdown]
# I'm not sure about anyone reading this, but this isn't exactly the kind of results I expected. Much of the code in the block above is standard for calculating tf-idf since the TfidfVectorizer was built to be used in a certain way. The index, i selects which row we want to base the tf-idf values since tf is a document-specific metric (expand on this later). Consequently, when we look at the first row, we see many words relating to Nigeria and stories since Chimamanda Ngozi Adichie is a Nigerian writer, telling her story (which involves reading stories). From there you understand why those words have the highest tf-idf weights.
#
# So why do some of our stop words have such high tf-idfs? Shouldn't they be common to many documents and thus have low idf? Great question, I'll be looking into that...
