# %% [markdown]
# # Data Preprocessing

# %%
# import packages
import numpy as np
import pandas as pd
import re

# %% [markdown]
# As a review from the last notebook, we scraped speech transcripts from James Clear's website on his ["Great Speeches" page](https://jamesclear.com/great-speeches) (where we took the top 10 which are sorted alphabetically by the orator's last name) and the lyrics from all songs in bestselling albums of all time (according to [Business Insider](https://www.businessinsider.com/50-best-selling-albums-all-time-2016-9)) from [AZLyrics](https://www.azlyrics.com/).
#
# Below are what our raw dataframes look like. Not bad if I do say so myself. Of course, there's a lot of preprocessing that has to be done, but it looks like we properly collected the data.

# %%
speech_df = pd.read_excel('speeches.xlsx', dtype=str)
speech_df
# Out:
#                      Orator                                Title  \
# 0  Chimamanda Ngozi Adichie         The Danger of a Single Story
# 1                Jeff Bezos  What Matters More Than Your Talents
# 2             John C. Bogle                               Enough
# 3               Brené Brown                 The Anatomy of Trust
# 4               John Cleese             Creativity in Management
# 5       William Deresiewicz              Solitude and Leadership
# 6           Richard Feynman                     Seeking New Laws
# 7               Neil Gaiman                        Make Good Art
# 8           John W. Gardner                     Personal Renewal
# 9         Elizabeth Gilbert         Your Elusive Creative Genius
#
#                                           Transcript  \
# 0  I'm a storyteller. And I would like to tell yo...
# 1  As a kid, I spent my summers with my grandpare...
# 2  Here’s how I recall the wonderful story that s...
# 3  Oh, it just feels like an incredible understat...
# 4  You know, when Video Arts asked me if I'd like...
# 5  My title must seem like a contradiction. What ...
# 6  What I want to talk to you about tonight is st...
# 7  I never really expected to find myself giving ...
# 8  I'm going to talk about “Self-Renewal.” One of...
# 9  I am a writer. Writing books is my profession ...
#
#                                                 Link
# 0  https://jamesclear.com/great-speeches/the-dang...
# 1  https://jamesclear.com/great-speeches/what-mat...
# 2  https://jamesclear.com/great-speeches/enough-b...
# 3  https://jamesclear.com/great-speeches/the-anat...
# 4  https://jamesclear.com/great-speeches/creativi...
# 5  https://jamesclear.com/great-speeches/solitude...
# 6  https://jamesclear.com/great-speeches/seeking-...
# 7  https://jamesclear.com/great-speeches/make-goo...
# 8  https://jamesclear.com/great-speeches/personal...
# 9  https://jamesclear.com/great-speeches/your-elu...

# %%
song_df =  pd.read_excel('songs.xlsx', dtype=str)
song_df
# Out:
#                   Artist                            Album  \
# 0        Michael Jackson                       "Thriller"
# 1                 Eagles               "Hotel California"
# 2           Led Zeppelin                "Led Zeppelin IV"
# 3             Pink Floyd                       "The Wall"
# 4                  AC/DC                  "Back In Black"
# 5           Garth Brooks                    "Double Live"
# 6  Hootie & The Blowfish              "Cracked Rear View"
# 7          Fleetwood Mac                        "Rumours"
# 8           Shania Twain                   "Come On Over"
# 9            The Beatles  "The Beatles (The White Album)"
#
#                                                Lyric  \
# 0  \n\r\nI said you wanna be startin' somethin'\n...
# 1  \n\r\nOn a dark desert highway, cool wind in m...
# 2  \n\r\nHey, hey mama, said the way you move\nGo...
# 3  \n\r\n(We came in)\n\nSo ya thought ya might l...
# 4  \n\r\nI'm rolling thunder pouring rain\nI'm co...
# 5  \n\r\nWe all came here for a party tonight\nAn...
# 6  \n\r\nYou got your big girl \nNow you've got y...
# 7  \n\r\nI know there's nothing to say\nSomeone h...
# 8  \n\r\nLet's go girls! Come on.\n\nI'm going ou...
# 9  \n\r\nOh, flew in by Miami Beach B.O.A.C.\nDid...
#
#                                    Artist_Link
# 0      https://www.azlyrics.com/j/jackson.html
# 1       https://www.azlyrics.com/e/eagles.html
# 2  https://www.azlyrics.com/l/ledzeppelin.html
# 3    https://www.azlyrics.com/p/pinkfloyd.html
# 4         https://www.azlyrics.com/a/acdc.html
# 5       https://www.azlyrics.com/b/brooks.html
# 6       https://www.azlyrics.com/h/hootie.html
# 7    https://www.azlyrics.com/f/fleetwood.html
# 8        https://www.azlyrics.com/t/twain.html
# 9      https://www.azlyrics.com/b/beatles.html

# %% [markdown]
# Below, I've combined our two raw data frames in the hopes that they can be preprocessed at the same time. Twenty rows may be a bit much for some people, but it's simple to take out rows so I felt it was best to have more rather than less. As an aside it also made webscraping a more interesting exercise since I needed to deal with different page and url formats.

# %%
comm_df =  pd.read_excel('communication_data.xlsx', dtype=str)
comm_df
# Out:
#                   Originator                                Title  \
# 0   Chimamanda Ngozi Adichie         The Danger of a Single Story
# 1                 Jeff Bezos  What Matters More Than Your Talents
# 2              John C. Bogle                               Enough
# 3                Brené Brown                 The Anatomy of Trust
# 4                John Cleese             Creativity in Management
# 5        William Deresiewicz              Solitude and Leadership
# 6            Richard Feynman                     Seeking New Laws
# 7                Neil Gaiman                        Make Good Art
# 8            John W. Gardner                     Personal Renewal
# 9          Elizabeth Gilbert         Your Elusive Creative Genius
# 10           Michael Jackson                           "Thriller"
# 11                    Eagles                   "Hotel California"
# 12              Led Zeppelin                    "Led Zeppelin IV"
# 13                Pink Floyd                           "The Wall"
# 14                     AC/DC                      "Back In Black"
# 15              Garth Brooks                        "Double Live"
# 16     Hootie & The Blowfish                  "Cracked Rear View"
# 17             Fleetwood Mac                            "Rumours"
# 18              Shania Twain                       "Come On Over"
# 19               The Beatles      "The Beatles (The White Album)"
#
#                                                Corpus  \
# 0   I'm a storyteller. And I would like to tell yo...
# 1   As a kid, I spent my summers with my grandpare...
# 2   Here’s how I recall the wonderful story that s...
# 3   Oh, it just feels like an incredible understat...
# 4   You know, when Video Arts asked me if I'd like...
# 5   My title must seem like a contradiction. What ...
# 6   What I want to talk to you about tonight is st...
# 7   I never really expected to find myself giving ...
# 8   I'm going to talk about “Self-Renewal.” One of...
# 9   I am a writer. Writing books is my profession ...
# 10  \n\r\nI said you wanna be startin' somethin'\n...
# 11  \n\r\nOn a dark desert highway, cool wind in m...
# 12  \n\r\nHey, hey mama, said the way you move\nGo...
# 13  \n\r\n(We came in)\n\nSo ya thought ya might l...
# 14  \n\r\nI'm rolling thunder pouring rain\nI'm co...
# 15  \n\r\nWe all came here for a party tonight\nAn...
# 16  \n\r\nYou got your big girl \nNow you've got y...
# 17  \n\r\nI know there's nothing to say\nSomeone h...
# 18  \n\r\nLet's go girls! Come on.\n\nI'm going ou...
# 19  \n\r\nOh, flew in by Miami Beach B.O.A.C.\nDid...
#
#                                                Source
# 0   https://jamesclear.com/great-speeches/the-dang...
# 1   https://jamesclear.com/great-speeches/what-mat...
# 2   https://jamesclear.com/great-speeches/enough-b...
# 3   https://jamesclear.com/great-speeches/the-anat...
# 4   https://jamesclear.com/great-speeches/creativi...
# 5   https://jamesclear.com/great-speeches/solitude...
# 6   https://jamesclear.com/great-speeches/seeking-...
# 7   https://jamesclear.com/great-speeches/make-goo...
# 8   https://jamesclear.com/great-speeches/personal...
# 9   https://jamesclear.com/great-speeches/your-elu...
# 10            https://www.azlyrics.com/j/jackson.html
# 11             https://www.azlyrics.com/e/eagles.html
# 12        https://www.azlyrics.com/l/ledzeppelin.html
# 13          https://www.azlyrics.com/p/pinkfloyd.html
# 14               https://www.azlyrics.com/a/acdc.html
# 15             https://www.azlyrics.com/b/brooks.html
# 16             https://www.azlyrics.com/h/hootie.html
# 17          https://www.azlyrics.com/f/fleetwood.html
# 18              https://www.azlyrics.com/t/twain.html
# 19            https://www.azlyrics.com/b/beatles.html

# %%
chars_to_keep = r"' "
def is_desired_char(c):
    return (c.isalpha() or c in chars_to_keep)

def keep_words(s):
    ret_str = ''.join(c for c in s if is_desired_char(c))
    return ' '.join(ret_str.split(' '))

# %%
# speech_df['Corpus'] = speech_df['Corpus'].str.lower()
# speech_df['Corpus'] = speech_df['Corpus'].apply(keep_words)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Topics
# * tf-idf
# * stemming

# %% [markdown]
# Not going to remove #s
